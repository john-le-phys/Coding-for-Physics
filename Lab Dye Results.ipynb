# %%
import numpy as np
import matplotlib.pyplot as plt  
import scipy.constants as constants
from pylab import *
from scipy.optimize import curve_fit

# %%
xdata,ydata=loadtxt('labdyeresults.txt', unpack = True)

# %%
print(xdata,ydata)
# Out:
# [2. 4. 6. 8.] [9.6 4.4 2.8 2.4]

# %%
plt.plot(xdata,ydata)
plt.xlabel("# of Droplets of Dye")
plt.ylabel("Voltage Difference between Signal and Reference")
plt.title("Dye Experiment Plot")
np.polyfit(np.log(xdata), ydata, 1)
print(np.log(xdata),ydata)
plt.plot(np.log(xdata),ydata)
# Out:
# [0.69314718 1.38629436 1.79175947 2.07944154] [9.6 4.4 2.8 2.4]
